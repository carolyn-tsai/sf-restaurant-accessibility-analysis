# %%
# Import dependencies

import os
import csv
import pandas as pd
import numpy as np

# Define file

file_1 = "final_clean_dog_data.csv"
file_2 = "final_wheelchair_data.csv"
file_3 = "final_data_both_dog_and_wheelchair.csv"

# Read the CSV files

dog_df_test = pd.read_csv(file_1, encoding="UTF-8", low_memory = False)    
wc_df = pd.read_csv(file_2, encoding="UTF-8", low_memory = False) 
wc_dog_df = pd.read_csv(file_3, encoding="UTF-8", low_memory = False)

# Preview Data Frame

dog_df.head()
# Out:
#                               name   latitude   longitude  \
# 0                      10th & Wood  37.810344 -122.302664
# 1               4505 Burgers & BBQ  37.776208 -122.440397
# 2  7 Mile House Sports Bar & Grill  37.704322 -122.407460
# 3                           a Mano  37.776899 -122.424030
# 4                         Absinthe  37.776995 -122.422885
#
#                                       address  zip_code  \
# 0         945 Wood St, Oakland, CA 94607-1311     94607
# 1  705 Divisadero St, San Francisco, CA 94117     94117
# 2      2800 Bayshore Blvd, Brisbane, CA 94005     94005
# 3       450 Hayes St, San Francisco, CA 94102     94102
# 4       398 Hayes St, San Francisco, CA 94102     94102
#
#                              website    neighborhood
# 0            http://10thandwood.com/         Oakland
# 1  http://www.4505burgersandbbq.com/  Haight-Ashbury
# 2         http://www.7milehouse.com/       Daly City
# 3               https://amanosf.com/           Hayes
# ...

# %%
wc_dog_df.head()
# Out:
#                  name   latitude   longitude  \
# 0  4505 Burgers & BBQ  37.776190 -122.438285
# 1         After Hours  37.742270 -122.499010
# 2           Aha Fresh  37.751351 -122.432183
# 3           Americano  37.793624 -122.392733
# 4   Bayshore Taqueria  37.743130 -122.405640
#
#                                              address  zip_code  \
# 0         705 Divisadero St, San Francisco, CA 94117     94117
# 1           3044 Taraval St, San Francisco, CA 94116     94116
# 2              4007 24th St, San Francisco, CA 94114     94114
# 3              8 Mission St, San Francisco, CA 94105     94105
# 4  300 Bayshore Blvd Suite A, San Francisco, CA 9...     94124
#
#                                              website
# 0  https://www.yelp.com/biz/4505-burgers-and-bbq-...
# 1  https://www.yelp.com/biz/after-hours-san-franc...
# 2  https://www.yelp.com/biz/aha-fresh-san-francis...
# 3       http://www.americanorestaurant.com/info.html
# ...

# %%
wc_dog_df["neighborhood"] = wc_dog_df["neighborhood"] = np.where(wc_dog_df["zip_code"] == 94102, "Hayes", 
                         np.where(wc_dog_df["zip_code"] == 94103, "South of Market",
                         np.where(wc_dog_df["zip_code"] == 94107, "Potrero Hill",
                         np.where(wc_dog_df["zip_code"] == 94108, "Chinatown",
                         np.where(wc_dog_df["zip_code"] == 94104, "Chinatown",         
                         np.where(wc_dog_df["zip_code"] == 94109, "Polk/Russian Hill (Nob Hill)",
                         np.where(wc_dog_df["zip_code"] == 94110, "Inner Mission/Bernal Heights",
                         np.where(wc_dog_df["zip_code"] == 94112, "Ingelside/Excelsior/Crocker-Amazon", 
                         np.where(wc_dog_df["zip_code"] == 94114, "Castro/Noe Valley",
                         np.where(wc_dog_df["zip_code"] == 94115, "Western Addition/Japantown", 
                         np.where(wc_dog_df["zip_code"] == 94116, "Parkside/Forest Hill", 
                         np.where(wc_dog_df["zip_code"] == 94117, "Haight-Ashbury",
                         np.where(wc_dog_df["zip_code"] == 94118, "Inner Richmond",
                         np.where(wc_dog_df["zip_code"] == 94121, "Outer Richmond",
                         np.where(wc_dog_df["zip_code"] == 94122, "Sunset",
                         np.where(wc_dog_df["zip_code"] == 94123, "Marina",    
                         np.where(wc_dog_df["zip_code"] == 94124, "Bayview/Hunters Point", 
                         np.where(wc_dog_df["zip_code"] == 94127, "St. Francis Wood/Miraloma/West Portal",
                         np.where(wc_dog_df["zip_code"] == 94131, "Twin Peaks/Glen Park",  
                         np.where(wc_dog_df["zip_code"] == 94132, "Lake Merced",
                         np.where(wc_dog_df["zip_code"] == 94133, "North Beach/Chinatown",
                         np.where(wc_dog_df["zip_code"] == 94129, "Presidio",     
                         np.where(wc_dog_df["zip_code"] == 94130, "Treasure Island",
                         np.where(wc_dog_df["zip_code"] == 94965, "Sausalito/Marin County",
                         np.where(wc_dog_df["zip_code"] == 94941, "Mill Valley", 
                         np.where(wc_dog_df["zip_code"] == 94105, "Embarcadero",
                         np.where(wc_dog_df["zip_code"] == 94111, "Embarcadero",         
                         np.where(wc_dog_df["zip_code"] == 94015, "Daly City",
                         np.where(wc_dog_df["zip_code"] == 94014, "Daly City",  
                         np.where(wc_dog_df["zip_code"] == 94005, "Daly City",         
                         np.where(wc_dog_df["zip_code"] == 94080, "Paradise Valley/South SF",
                         np.where(wc_dog_df["zip_code"] == 94158, "Mission Bay",
                         np.where(wc_dog_df["zip_code"] == 94804, "Richmond (City)",
                         np.where(wc_dog_df["zip_code"] == 94530, "Richmond (City)", 
                         np.where(wc_dog_df["zip_code"] == 94010, "Burlingame",
                         np.where(wc_dog_df["zip_code"] == 94966, "Tiburon",
                         np.where(wc_dog_df["zip_code"] == 94920, "Tiburon",
                         np.where(wc_dog_df["zip_code"] == 95814, "Sacramento", 
                         np.where(wc_dog_df["zip_code"] == 94044, "Pacifica", 
                         np.where(wc_dog_df["zip_code"] == 94010, "Alameda",
                         np.where(wc_dog_df["zip_code"] == 94710, "Alameda",
                         np.where(wc_dog_df["zip_code"] == 94706, "Alameda",
                         np.where(wc_dog_df["zip_code"] == 94706, "Alameda", 
                         np.where(wc_dog_df["zip_code"] == 94501, "Alameda",
                         np.where(wc_dog_df["zip_code"] == 94607, "Oakland",
                         np.where(wc_dog_df["zip_code"] == 94612, "Oakland", 
                         np.where(wc_dog_df["zip_code"] == 94609, "Oakland", 
                         np.where(wc_dog_df["zip_code"] == 94702, "Berkeley", 
                         np.where(wc_dog_df["zip_code"] == 94707, "Berkeley",
                         np.where(wc_dog_df["zip_code"] == 94608, "Emeryville",         
                                  "UNKNOWN"))))))))))))))))))))))))))))))))))))))))))))))))))

# %%
unknown = wc_dog_df[wc_dog_df["neighborhood"] == "UNKNOWN"]

unknown
# Out:
# Empty DataFrame
# Columns: [name, latitude, longitude, address, zip_code, website, neighborhood]
# Index: []

# %%
wc_dog_df.to_csv("both_wheelchair_dog_rest_neighborhoods.csv", index=False)

# %%
wc_df["neighborhood"] = wc_df["neighborhood"] = np.where(wc_df["zip_code"] == 94102, "Hayes", 
                         np.where(wc_df["zip_code"] == 94103, "South of Market",
                         np.where(wc_df["zip_code"] == 94107, "Potrero Hill",
                         np.where(wc_df["zip_code"] == 94108, "Chinatown",
                         np.where(wc_df["zip_code"] == 94104, "Chinatown",         
                         np.where(wc_df["zip_code"] == 94109, "Polk/Russian Hill (Nob Hill)",
                         np.where(wc_df["zip_code"] == 94110, "Inner Mission/Bernal Heights",
                         np.where(wc_df["zip_code"] == 94112, "Ingelside/Excelsior/Crocker-Amazon", 
                         np.where(wc_df["zip_code"] == 94114, "Castro/Noe Valley",
                         np.where(wc_df["zip_code"] == 94115, "Western Addition/Japantown", 
                         np.where(wc_df["zip_code"] == 94116, "Parkside/Forest Hill", 
                         np.where(wc_df["zip_code"] == 94117, "Haight-Ashbury",
                         np.where(wc_df["zip_code"] == 94118, "Inner Richmond",
                         np.where(wc_df["zip_code"] == 94121, "Outer Richmond",
                         np.where(wc_df["zip_code"] == 94122, "Sunset",
                         np.where(wc_df["zip_code"] == 94123, "Marina",    
                         np.where(wc_df["zip_code"] == 94124, "Bayview/Hunters Point", 
                         np.where(wc_df["zip_code"] == 94127, "St. Francis Wood/Miraloma/West Portal",
                         np.where(wc_df["zip_code"] == 94131, "Twin Peaks/Glen Park",  
                         np.where(wc_df["zip_code"] == 94132, "Lake Merced",
                         np.where(wc_df["zip_code"] == 94133, "North Beach/Chinatown",
                         np.where(wc_df["zip_code"] == 94129, "Presidio",     
                         np.where(wc_df["zip_code"] == 94130, "Treasure Island",
                         np.where(wc_df["zip_code"] == 94965, "Sausalito/Marin County",
                         np.where(wc_df["zip_code"] == 94941, "Mill Valley", 
                         np.where(wc_df["zip_code"] == 94105, "Embarcadero",
                         np.where(wc_df["zip_code"] == 94111, "Embarcadero",         
                         np.where(wc_df["zip_code"] == 94158, "Mission Bay",
                         np.where(wc_df["zip_code"] == 94134, "Portola/Visitacion Valley",
                         np.where(wc_df["zip_code"] == 94080, "Paradise Valley/South SF",
                         np.where(wc_df["zip_code"] == 94015, "Daly City",
                         np.where(wc_df["zip_code"] == 94014, "Daly City",  
                         np.where(wc_df["zip_code"] == 94005, "Daly City",
                         np.where(wc_df["zip_code"] == 94920, "Tiburon",         
                                  "UNKNOWN"))))))))))))))))))))))))))))))))))

# %%
unknown = wc_df[wc_df["neighborhood"] == "UNKNOWN"]

unknown
# Out:
# Empty DataFrame
# Columns: [name, latitude, longitude, address, zip_code, website, neighborhood]
# Index: []

# %%
wc_df["neighborhood"].value_counts()
# Out:
# South of Market                          106
# Inner Mission/Bernal Heights             101
# Hayes                                     88
# Polk/Russian Hill (Nob Hill)              78
# Embarcadero                               75
# North Beach/Chinatown                     66
# Potrero Hill                              59
# Haight-Ashbury                            53
# Sunset                                    49
# Inner Richmond                            48
# Marina                                    42
# Chinatown                                 40
# Western Addition/Japantown                36
# Outer Richmond                            32
# Castro/Noe Valley                         29
# Parkside/Forest Hill                      18
# Ingelside/Excelsior/Crocker-Amazon        15
# Lake Merced                               12
# Bayview/Hunters Point                     12
# St. Francis Wood/Miraloma/West Portal     11
# Mission Bay                                9
# ...

# %%
wc_df.head()
# Out:
#                                name   latitude   longitude  \
# 0  1428 HAIGHT Patio Cafe & Crepery  37.770149 -122.445869
# 1                           20 Spot  37.758340 -122.420360
# 2                        3rd Cousin  37.739070 -122.413660
# 3                4505 Burgers & BBQ  37.776190 -122.438285
# 4                  5A5 Steak Lounge  37.796997 -122.400061
#
#                                       address  zip_code  \
# 0     1428 Haight St, San Francisco, CA 94117     94117
# 1       3565 20th St, San Francisco, CA 94110     94110
# 2   919 Cortland Ave, San Francisco, CA 94110     94110
# 3  705 Divisadero St, San Francisco, CA 94117     94117
# 4     244 Jackson St, San Francisco, CA 94111     94111
#
#                                              website  \
# 0  https://www.yelp.com/biz/1428-haight-patio-caf...
# 1  https://www.yelp.com/biz/20-spot-san-francisco...
# 2  https://www.yelp.com/biz/3rd-cousin-san-franci...
# ...

# %%
wc_df.to_csv("wheelchair_rest_neighborhoods.csv", index=False)

# %%
dog_df.dtypes
# Out:
# name          object
# latitude     float64
# longitude    float64
# address       object
# zip_code       int64
# website       object
# dtype: object

# %%
dog_df["neighborhood"] = np.where(dog_df["zip_code"] == 94102, "Hayes", 
                         np.where(dog_df["zip_code"] == 94103, "South of Market",
                         np.where(dog_df["zip_code"] == 94107, "Potrero Hill",
                         np.where(dog_df["zip_code"] == 94108, "Chinatown",
                         np.where(dog_df["zip_code"] == 94104, "Chinatown",         
                         np.where(dog_df["zip_code"] == 94109, "Polk/Russian Hill (Nob Hill)",
                         np.where(dog_df["zip_code"] == 94110, "Inner Mission/Bernal Heights",
                         np.where(dog_df["zip_code"] == 94112, "Ingelside/Excelsior/Crocker-Amazon", 
                         np.where(dog_df["zip_code"] == 94114, "Castro/Noe Valley",
                         np.where(dog_df["zip_code"] == 94115, "Western Addition/Japantown", 
                         np.where(dog_df["zip_code"] == 94116, "Parkside/Forest Hill", 
                         np.where(dog_df["zip_code"] == 94117, "Haight-Ashbury",
                         np.where(dog_df["zip_code"] == 94118, "Inner Richmond",
                         np.where(dog_df["zip_code"] == 94121, "Outer Richmond",
                         np.where(dog_df["zip_code"] == 94122, "Sunset",
                         np.where(dog_df["zip_code"] == 94123, "Marina",    
                         np.where(dog_df["zip_code"] == 94124, "Bayview/Hunters Point", 
                         np.where(dog_df["zip_code"] == 94127, "St. Francis Wood/Miraloma/West Portal",
                         np.where(dog_df["zip_code"] == 94131, "Twin Peaks/Glen Park",  
                         np.where(dog_df["zip_code"] == 94132, "Lake Merced",
                         np.where(dog_df["zip_code"] == 94133, "North Beach/Chinatown",
                         np.where(dog_df["zip_code"] == 94129, "Presidio",     
                         np.where(dog_df["zip_code"] == 94130, "Treasure Island",
                         np.where(dog_df["zip_code"] == 94965, "Sausalito/Marin County",
                         np.where(dog_df["zip_code"] == 94941, "Mill Valley", 
                         np.where(dog_df["zip_code"] == 94105, "Embarcadero",
                         np.where(dog_df["zip_code"] == 94111, "Embarcadero",         
                         np.where(dog_df["zip_code"] == 94015, "Daly City",
                         np.where(dog_df["zip_code"] == 94014, "Daly City",  
                         np.where(dog_df["zip_code"] == 94005, "Daly City",         
                         np.where(dog_df["zip_code"] == 94080, "Paradise Valley/South SF",
                         np.where(dog_df["zip_code"] == 94158, "Mission Bay",
                         np.where(dog_df["zip_code"] == 94804, "Richmond (City)",
                         np.where(dog_df["zip_code"] == 94530, "Richmond (City)", 
                         np.where(dog_df["zip_code"] == 94010, "Burlingame",
                         np.where(dog_df["zip_code"] == 94966, "Tiburon",
                         np.where(dog_df["zip_code"] == 94920, "Tiburon",
                         np.where(dog_df["zip_code"] == 95814, "Sacramento", 
                         np.where(dog_df["zip_code"] == 94044, "Pacifica", 
                         np.where(dog_df["zip_code"] == 94010, "Alameda",
                         np.where(dog_df["zip_code"] == 94710, "Alameda",
                         np.where(dog_df["zip_code"] == 94706, "Alameda",
                         np.where(dog_df["zip_code"] == 94706, "Alameda", 
                         np.where(dog_df["zip_code"] == 94501, "Alameda",
                         np.where(dog_df["zip_code"] == 94607, "Oakland",
                         np.where(dog_df["zip_code"] == 94612, "Oakland", 
                         np.where(dog_df["zip_code"] == 94609, "Oakland", 
                         np.where(dog_df["zip_code"] == 94702, "Berkeley", 
                         np.where(dog_df["zip_code"] == 94707, "Berkeley",
                         np.where(dog_df["zip_code"] == 94608, "Emeryville",         
                                  "UNKNOWN"))))))))))))))))))))))))))))))))))))))))))))))))))

# %%
unknown = dog_df[dog_df["neighborhood"] == "UNKNOWN"]

unknown
# Out:
# Empty DataFrame
# Columns: [name, latitude, longitude, address, zip_code, website, neighborhood]
# Index: []

# %%
def getNeighborhoodsfromZip(datadf):
    datadf["neighborhood"] = np.where(datadf["zip_code"] == 94102, "Hayes", 
                         np.where(datadf["zip_code"] == 94103, "South of Market",
                         np.where(datadf["zip_code"] == 94107, "Potrero Hill",
                         np.where(datadf["zip_code"] == 94108, "Chinatown",
                         np.where(datadf["zip_code"] == 94104, "Chinatown",         
                         np.where(datadf["zip_code"] == 94109, "Polk/Russian Hill (Nob Hill)",
                         np.where(datadf["zip_code"] == 94110, "Inner Mission/Bernal Heights",
                         np.where(datadf["zip_code"] == 94112, "Ingelside/Excelsior/Crocker-Amazon", 
                         np.where(datadf["zip_code"] == 94114, "Castro/Noe Valley",
                         np.where(datadf["zip_code"] == 94115, "Western Addition/Japantown", 
                         np.where(datadf["zip_code"] == 94116, "Parkside/Forest Hill", 
                         np.where(datadf["zip_code"] == 94117, "Haight-Ashbury",
                         np.where(datadf["zip_code"] == 94118, "Inner Richmond",
                         np.where(datadf["zip_code"] == 94121, "Outer Richmond",
                         np.where(datadf["zip_code"] == 94122, "Sunset",
                         np.where(datadf["zip_code"] == 94123, "Marina",    
                         np.where(datadf["zip_code"] == 94124, "Bayview/Hunters Point", 
                         np.where(datadf["zip_code"] == 94127, "St. Francis Wood/Miraloma/West Portal",
                         np.where(datadf["zip_code"] == 94131, "Twin Peaks/Glen Park",  
                         np.where(datadf["zip_code"] == 94132, "Lake Merced",
                         np.where(datadf["zip_code"] == 94133, "North Beach/Chinatown",
                         np.where(datadf["zip_code"] == 94129, "Presidio",     
                         np.where(datadf["zip_code"] == 94130, "Treasure Island",
                         np.where(datadf["zip_code"] == 94965, "Sausalito/Marin County",
                         np.where(datadf["zip_code"] == 94941, "Mill Valley", 
                         np.where(datadf["zip_code"] == 94105, "Embarcadero",
                         np.where(datadf["zip_code"] == 94111, "Embarcadero",         
                         np.where(datadf["zip_code"] == 94015, "Daly City",
                         np.where(datadf["zip_code"] == 94014, "Daly City",  
                         np.where(datadf["zip_code"] == 94005, "Daly City",         
                         np.where(datadf["zip_code"] == 94080, "Paradise Valley/South SF",
                         np.where(datadf["zip_code"] == 94158, "Mission Bay",
                         np.where(datadf["zip_code"] == 94804, "Richmond (City)",
                         np.where(datadf["zip_code"] == 94530, "Richmond (City)", 
                         np.where(datadf["zip_code"] == 94010, "Burlingame",
                         np.where(datadf["zip_code"] == 94966, "Tiburon",
                         np.where(datadf["zip_code"] == 94920, "Tiburon",
                         np.where(datadf["zip_code"] == 95814, "Sacramento", 
                         np.where(datadf["zip_code"] == 94044, "Pacifica", 
                         np.where(datadf["zip_code"] == 94010, "Alameda",
                         np.where(datadf["zip_code"] == 94710, "Alameda",
                         np.where(datadf["zip_code"] == 94706, "Alameda",
                         np.where(datadf["zip_code"] == 94706, "Alameda", 
                         np.where(datadf["zip_code"] == 94501, "Alameda",
                         np.where(datadf["zip_code"] == 94607, "Oakland",
                         np.where(datadf["zip_code"] == 94612, "Oakland", 
                         np.where(datadf["zip_code"] == 94609, "Oakland", 
                         np.where(datadf["zip_code"] == 94702, "Berkeley", 
                         np.where(datadf["zip_code"] == 94707, "Berkeley",
                         np.where(datadf["zip_code"] == 94608, "Emeryville",         
                                  "UNKNOWN"))))))))))))))))))))))))))))))))))))))))))))))))))
    return datadf

# %%
neighborhoods_dog = getNeighborhoodsfromZip(dog_df_test)

# %%
neighborhoods_dog.head()
# Out:
#                               name   latitude   longitude  \
# 0                      10th & Wood  37.810344 -122.302664
# 1               4505 Burgers & BBQ  37.776208 -122.440397
# 2  7 Mile House Sports Bar & Grill  37.704322 -122.407460
# 3                           a Mano  37.776899 -122.424030
# 4                         Absinthe  37.776995 -122.422885
#
#                                       address  zip_code  \
# 0         945 Wood St, Oakland, CA 94607-1311     94607
# 1  705 Divisadero St, San Francisco, CA 94117     94117
# 2      2800 Bayshore Blvd, Brisbane, CA 94005     94005
# 3       450 Hayes St, San Francisco, CA 94102     94102
# 4       398 Hayes St, San Francisco, CA 94102     94102
#
#                              website    neighborhood
# 0            http://10thandwood.com/         Oakland
# 1  http://www.4505burgersandbbq.com/  Haight-Ashbury
# 2         http://www.7milehouse.com/       Daly City
# 3               https://amanosf.com/           Hayes
# ...

# %%
dog_df["neighborhood"].value_counts()
# Out:
# Inner Mission/Bernal Heights             35
# Haight-Ashbury                           28
# Castro/Noe Valley                        24
# Marina                                   22
# North Beach/Chinatown                    20
# Alameda                                  19
# Potrero Hill                             18
# South of Market                          17
# Sunset                                   17
# Sausalito/Marin County                   17
# Polk/Russian Hill (Nob Hill)             14
# Embarcadero                              14
# Hayes                                    14
# Chinatown                                12
# Inner Richmond                           10
# Daly City                                10
# Berkeley                                 10
# Mill Valley                               9
# Western Addition/Japantown                9
# Outer Richmond                            8
# Emeryville                                7
# ...

# %%
dog_df.head()
# Out:
#                               name   latitude   longitude  \
# 0                      10th & Wood  37.810344 -122.302664
# 1               4505 Burgers & BBQ  37.776208 -122.440397
# 2  7 Mile House Sports Bar & Grill  37.704322 -122.407460
# 3                           a Mano  37.776899 -122.424030
# 4                         Absinthe  37.776995 -122.422885
#
#                                       address  zip_code  \
# 0         945 Wood St, Oakland, CA 94607-1311     94607
# 1  705 Divisadero St, San Francisco, CA 94117     94117
# 2      2800 Bayshore Blvd, Brisbane, CA 94005     94005
# 3       450 Hayes St, San Francisco, CA 94102     94102
# 4       398 Hayes St, San Francisco, CA 94102     94102
#
#                              website    neighborhood
# 0            http://10thandwood.com/         Oakland
# 1  http://www.4505burgersandbbq.com/  Haight-Ashbury
# 2         http://www.7milehouse.com/       Daly City
# 3               https://amanosf.com/           Hayes
# ...

# %%
dog_df.to_csv("dog_rest_neighborhoods.csv", index=False)

# %%
dog_df["neighborhood"] = np.where(dog_df["zip_code"] == 94710, 
                                  np.where(dog_df["zip_code"] == 94608,
                                  np.where(dog_df["zip_code"] == 94706,
                                  np.where(dog_df["zip_code"] == 94706,
                                  np.where(dog_df["zip_code"] == 94501,         
                                           "Alameda",

# %%
dog_df.head()
# Out:
#                               name   latitude   longitude  \
# 0                      10th & Wood  37.810344 -122.302664
# 1               4505 Burgers & BBQ  37.776208 -122.440397
# 2  7 Mile House Sports Bar & Grill  37.704322 -122.407460
# 3                           a Mano  37.776899 -122.424030
# 4                         Absinthe  37.776995 -122.422885
#
#                                       address  zip_code  \
# 0         945 Wood St, Oakland, CA 94607-1311     94607
# 1  705 Divisadero St, San Francisco, CA 94117     94117
# 2      2800 Bayshore Blvd, Brisbane, CA 94005     94005
# 3       450 Hayes St, San Francisco, CA 94102     94102
# 4       398 Hayes St, San Francisco, CA 94102     94102
#
#                              website              neighborhood
# 0            http://10thandwood.com/  Outside of San Francisco
# 1  http://www.4505burgersandbbq.com/            Haight-Ashbury
# 2         http://www.7milehouse.com/  Outside of San Francisco
# ...

# %%
 np.where(dog_df["zip_code"] == 94710, "Alameda County",   
                         np.where(dog_df["zip_code"] == 94608, "Alameda County"

# %%
a = np.where(dog_df["zip_code"] == 94710, dog_df["zip_code"] == 94608, "Alameda County")

# %%
dog_df.head()
# Out:
#                               name   latitude   longitude  \
# 0                      10th & Wood  37.810344 -122.302664
# 1               4505 Burgers & BBQ  37.776208 -122.440397
# 2  7 Mile House Sports Bar & Grill  37.704322 -122.407460
# 3                           a Mano  37.776899 -122.424030
# 4                         Absinthe  37.776995 -122.422885
#
#                                       address  zip_code  \
# 0         945 Wood St, Oakland, CA 94607-1311     94607
# 1  705 Divisadero St, San Francisco, CA 94117     94117
# 2      2800 Bayshore Blvd, Brisbane, CA 94005     94005
# 3       450 Hayes St, San Francisco, CA 94102     94102
# 4       398 Hayes St, San Francisco, CA 94102     94102
#
#                              website              neighborhood
# 0            http://10thandwood.com/  Outside of San Francisco
# 1  http://www.4505burgersandbbq.com/            Haight-Ashbury
# 2         http://www.7milehouse.com/  Outside of San Francisco
# ...

# %%
outside_SF = dog_df[dog_df["neighborhood"] == "Outside of San Francisco"]

# %%
outside_SF["zip_code"].value_counts()
# Out:
# 94965    17
# 94710    10
# 94941     9
# 94105     9
# 94702     8
# 94608     7
# 94706     7
# 94104     6
# 94015     6
# 94080     5
# 94111     5
# 94158     4
# 94010     3
# 94607     2
# 94707     2
# 94005     2
# 94501     2
# 94014     2
# 94530     2
# 10264     1
# 94113     1
# 94044     1
# 94966     1
# 94612     1
# 94609     1
# 95814     1
# 94920     1
# 94804     1
# Name: zip_code, dtype: int64

# %%
b = np.where(dog_df["zip_code"] == 94102)
b
# Out:
# (array([  3,   4,  38,  50,  78, 173, 226, 236, 256, 285, 290, 299, 311,
#         369], dtype=int64),)

# %%
dog_df["neighborhood"] = np.where(dog_df["zip_code"] == 94102, "Hayes", np.where(dog_df["zip_code"] == 94103, "South of Market", "NONE"))

# %%
dog_df.head()
# Out:
#                               name   latitude   longitude  \
# 0                      10th & Wood  37.810344 -122.302664
# 1               4505 Burgers & BBQ  37.776208 -122.440397
# 2  7 Mile House Sports Bar & Grill  37.704322 -122.407460
# 3                           a Mano  37.776899 -122.424030
# 4                         Absinthe  37.776995 -122.422885
#
#                                       address  zip_code  \
# 0         945 Wood St, Oakland, CA 94607-1311     94607
# 1  705 Divisadero St, San Francisco, CA 94117     94117
# 2      2800 Bayshore Blvd, Brisbane, CA 94005     94005
# 3       450 Hayes St, San Francisco, CA 94102     94102
# 4       398 Hayes St, San Francisco, CA 94102     94102
#
#                              website neighborhood
# 0            http://10thandwood.com/         NONE
# 1  http://www.4505burgersandbbq.com/         NONE
# 2         http://www.7milehouse.com/         NONE
# 3               https://amanosf.com/        Hayes
# ...

# %%
dog_df["neighborhood"] = np.where(dog_df["zip_code"] == 94607, "Haight-Ashbury")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e423ba1b59c6> in <module>
# ----> 1 dog_df["neighborhood"] = np.where(dog_df["zip_code"] == 94607, "Haight-Ashbury")
#
# ValueError: either both or neither of x and y should be given

# %%
dog_df["zip_code"][3]
# Out:
# 94102

# %%
for restaurant in dog_df["zip_code"]:
    if dog_df["zip_code"][restaurant] == 94102:
        neighborhood = "Hayes Valley/Tenderloin/North of Market"
        dog_df["neighborhood"].append(neighborhood)
    else:
        neighborhood = "NONE"
        dog_df["neighborhood"].append(neighborhood)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-e3a817e99866> in <module>
#       1 for restaurant in dog_df["zip_code"]:
# ----> 2     if dog_df["zip_code"][restaurant] == 94102:
#       3         neighborhood = "Hayes Valley/Tenderloin/North of Market"
#       4         dog_df["neighborhood"].append(neighborhood)
#       5     else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4721         k = self._convert_scalar_indexer(k, kind="getitem")
#    4722         try:
# ...
