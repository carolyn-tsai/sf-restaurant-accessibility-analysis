# %%
# Import dependencies

import csv
import requests
import pandas as pd

# %%
# Define api key, headers, and URL

API_KEY = "API KEY HERE!"
HEADERS = {"Authorization":  "Bearer %s" % API_KEY}
URL = "https://api.yelp.com/v3/businesses/search"

# Create empty list for yelp data to be appended
            
wheelchair_yelp_data = []
offset = 0

# API call limit is 1,000 for business attribute search
# Create loop to get data based off of given parameters

for x in range(20):
    offset = x *50
    params = {
        "term":"restaurants",
        "limit": 50,
        "offset": offset,
        "location":"San Francisco",
        "attributes": "wheelchair_accessible"
    }
    
    # Make Yelp API request and store response in variable 

    yelp_response = requests.get(URL, params= params, headers = HEADERS)

    # Store the json response in a varaible
    
    wheelchair = yelp_response.json()

    # Loop through each business entry to get data in correct column
    
    for business in wheelchair["businesses"]:
        wc_columns = {
            "alias":business["categories"][0]["alias"],
            "name":business["name"],
            "latitude":str(business["coordinates"]["latitude"]),
            "longitude":str(business["coordinates"]["longitude"]),
            "is_closed":business["is_closed"], 
            "rating":business["rating"], 
            "image_url":business["image_url"],
            "review_count":business["review_count"],
            "transactions":business["transactions"]
        }
        
        # Append the data to the empty list
        
        wheelchair_yelp_data.append(wc_columns)

# Convert the array to a pandas dataframe

wc_data_df = pd.DataFrame(wheelchair_yelp_data)

# Rename "alias" column to "category"

wc_data_df.rename(columns={"alias": "category"}, inplace=True)

# %%
# Display the head of dataframe to check that data makes sense

wc_data_df.head()
# Out:
#       category                            name    latitude     longitude  \
# 0      seafood           Fog Harbor Fish House   37.809041   -122.410233
# 1        ramen               Marufuku Ramen SF   37.785155   -122.432075
# 2         thai  Farmhouse Kitchen Thai Cuisine  37.7602179  -122.4110749
# 3       korean                           um.ma     37.7655    -122.46608
# 4  newamerican                            MaMo    37.80384    -122.43366
#
#    is_closed  rating                                          image_url  \
# 0      False     4.0  https://s3-media1.fl.yelpcdn.com/bphoto/Lv7tIR...
# 1      False     4.5  https://s3-media2.fl.yelpcdn.com/bphoto/2lUFO5...
# 2      False     4.0  https://s3-media1.fl.yelpcdn.com/bphoto/woO06s...
# 3      False     4.0  https://s3-media4.fl.yelpcdn.com/bphoto/9ILbI4...
# 4      False     5.0  https://s3-media2.fl.yelpcdn.com/bphoto/O507g5...
#
#    review_count                                transactions  region
# 0          5871                    [restaurant_reservation]  region
# 1          2757                                          []  region
# 2          2279  [pickup, delivery, restaurant_reservation]  region
# 3           231                    [restaurant_reservation]  region
# 4            86                    [restaurant_reservation]  region

# %%
# Check to see if max rows was called (should be 1000)

len(data_csv)
# Out:
# 1000

# %%
# Save the dataframe to a csv file

data_csv.to_csv("wheelchair_yelp_data.csv", index=False)
